# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-libraries-and-packages" data-toc-modified-id="Import-libraries-and-packages-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import libraries and packages</a></span><ul class="toc-item"><li><span><a href="#Load-in-review-data" data-toc-modified-id="Load-in-review-data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Load in review data</a></span></li><li><span><a href="#Clean-data" data-toc-modified-id="Clean-data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Clean data</a></span></li></ul></li><li><span><a href="#add-user-inputs-into-dataframe" data-toc-modified-id="add-user-inputs-into-dataframe-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>add user inputs into dataframe</a></span></li><li><span><a href="#Combine-dataframes" data-toc-modified-id="Combine-dataframes-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Combine dataframes</a></span></li><li><span><a href="#create-separate-dataframes-for-places-and-users-after-applying-cosine-similarity" data-toc-modified-id="create-separate-dataframes-for-places-and-users-after-applying-cosine-similarity-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>create separate dataframes for places and users after applying cosine similarity</a></span></li><li><span><a href="#Recommender-functions:" data-toc-modified-id="Recommender-functions:-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Recommender functions:</a></span></li><li><span><a href="#Example-of-top-recommendations-for-a-place" data-toc-modified-id="Example-of-top-recommendations-for-a-place-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Example of top recommendations for a place</a></span><ul class="toc-item"><li><span><a href="#Plotly" data-toc-modified-id="Plotly-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Plotly</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Import libraries and packages

# %%
import glob
import os

import pandas as pd
import numpy as np
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances

import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot
import cufflinks as cf
import matplotlib.pyplot as plt 
import seaborn as sns 
  
sns.set_style('white') 
# %matplotlib inline

# %% [markdown]
# ## Load in review data

# %%
df = pd.concat([pd.read_csv(file, index_col=0) for file in glob.glob('./reviews/text_*.csv')])

# %% [markdown]
# ## Clean data

# %%
df = df[df['rating'] != 'no rating']
df = df[~df['place_name'].str.contains('-- CLOSED')]
df = df[~df['category'].str.contains('City')]
df['rating'] = df['rating'].map(lambda x: int(x.split(' ')[0]))
df = df.reset_index(drop=True)

# %%
df
# Out:
#                                         place_name    category  rating  \
# 0           Ann and Roy Butler Hike and Bike Trail  Attraction       5
# 1                         Mozart's Coffee Roasters  Restaurant       5
# 2                        McKinney Falls State Park  Attraction       5
# 3                                     Waller Creek  Attraction       5
# 4                           Vandegrift High School  Attraction       5
# 5                      Steiner Ranch Hiking Trails  Attraction       5
# 6                Austin City Limits Music Festival  Attraction       5
# 7                Mayfield Park Cottage and Gardens  Attraction       5
# 8                               360 Bridge Lookout  Attraction       5
# 9                             Restoration Hardware  Attraction       5
# 10                                      360 Bridge  Attraction       5
# 11                                     Lake Austin  Attraction       5
# 12                                        Wig Ave.  Attraction       5
# 13                                Triple Z Threadz  Attraction       5
# 14                                      Chi'lantro  Restaurant       5
# 15                Umlauf Sculpture Garden & Museum  Attraction       5
# 16                   Ginnys Little Longhorn Saloon  Attraction       5
# 17                                 Mister Car Wash  Attraction       5
# 18                                 Spicewood Farms  Attraction       5
# 19                          Selma Hughes Park Road  Attraction       5
# 20                           Avenue Five Institute  Attraction       5
# 21                          Barton Creek Greenbelt  Attraction       5
# 22                              Red Bud Isle Park   Attraction       5
# 23                                          Bar 96  Attraction       5
# 24            The Grove Wine Bar / Kitchen Lakeway  Restaurant       5
# 25               Blue Starlite Mini Urban Drive In  Attraction       5
# 26                          Cedar Street Courtyard  Attraction       5
# 27                                   Torchy's Taco  Restaurant       5
# 28                                 Bent Oak Winery  Attraction       5
# 29                  Little Sheep Mongolian Hot Pot  Restaurant       5
# ...                                            ...         ...     ...
# 5254            Lady Bird Lake Hike-and-Bike Trail  Attraction       5
# 5255                                          Uchi  Restaurant       5
# 5256             Austin City Limits Music Festival  Attraction       5
# 5257                    Whole Foods Market - Lamar  Attraction       5
# 5258                           Barton Springs Pool  Attraction       5
# 5259                      Zilker Metropolitan Park  Attraction       4
# 5260                                     Nomad Bar  Restaurant       5
# 5261                        Supermercado El Rancho  Restaurant       5
# 5262                                    Taco Shack  Restaurant       5
# 5263                Tres Amigos Cantina Restaurant  Restaurant       5
# 5264                              Uncommon Objects  Attraction       4
# 5265                                        Luby's  Restaurant       2
# 5266                                 Threadgill's   Restaurant       2
# 5267                  Mangia Chicago Stuffed Pizza  Restaurant       1
# 5268                          Hyatt Regency Austin       Hotel       1
# 5269                       The Carillon Restaurant  Restaurant       5
# 5270                Rudy's Country Store & Bar-B-Q  Restaurant       4
# 5271                         South Congress Avenue  Attraction       4
# 5272  Austin Bergstrom International Airport (AUS)  Attraction       4
# 5273                     South Congress Bridge Bat  Attraction       4
# 5274                          Hyatt Regency Austin       Hotel       3
# 5275                                Torchy's Tacos  Restaurant       5
# 5276                                 Torchy's Taco  Restaurant       5
# 5277                                Torchy's Tacos  Restaurant       5
# 5278                                Torchy's Tacos  Restaurant       5
# 5279                                Torchy's Tacos  Restaurant       5
# 5280                              Kerbey Lane Cafe  Restaurant       5
# 5281             Mayfield Park and Nature Preserve  Attraction       5
# 5282                                    Mt Bonnell  Attraction       5
# 5283                     McKinney Falls State Park  Attraction       5
#
#               user_name                                        review_text
# 0       what-moms-think  This Hike or Bike trail is just wonderful! The...
# 1       what-moms-think  Mozart's is a great place to sit by the beauti...
# 2       what-moms-think  Although it’s Fall in Austin right now and the...
# 3       what-moms-think  The art show at Waller Creek does not disappoi...
# 4       what-moms-think  This local highschool holds some amazing commu...
# 5       what-moms-think  22 Miles of pristine trails, streams, swimming...
# 6       what-moms-think  My experience at ACL the last 2 yrs has been i...
# 7       what-moms-think  Nice hiking and walking grounds for families a...
# 8       what-moms-think  There’s a little place to pull your car off th...
# 9       what-moms-think  Just WOW! This giant 4 story building has it a...
# 10      what-moms-think  There’s a little place to pull your car off th...
# 11      what-moms-think  Find a bank along the lake and relax with your...
# 12      what-moms-think  Wig Ave was a first for me; I had so much fun!...
# 13      what-moms-think  Triple z is full of fun flair! You've got wall...
# 14      what-moms-think  Omg! Such an amazing little food shop! AgF kor...
# 15      what-moms-think  Umlauf is a quintessential sculpture garden lo...
# 16      what-moms-think                                            no text
# 17      what-moms-think  First time customer and I was very pleased. Th...
# 18      what-moms-think  This is a great horse facility and riding aren...
# 19      what-moms-think  Besides wishing that the association would tak...
# 20      what-moms-think                                            no text
# 21      what-moms-think  Great hiking trails, swimming spots and picnic...
# 22      what-moms-think  Red but I'll park is such an amazing spot righ...
# 23      what-moms-think                                            no text
# 24      what-moms-think                                            no text
# 25      what-moms-think  This little gem just on the fringe of Austin i...
# 26      what-moms-think  What a great place to end up and be surprised ...
# 27      what-moms-think  Torchey's is DAMN GOOD! we love everything abo...
# 28      what-moms-think  Very friendly atmosphere and very close to 620...
# 29      what-moms-think  I stumbled upon this place during a visit to t...
# ...                 ...                                                ...
# 5254         david-k_25  Everyone loves the hike and bike trail... jog ...
# 5255         david-k_25  Walk to Uchi, consistently ranked one of the b...
# 5256         david-k_25  Our house is perfectly situated for ACL... clo...
# 5257         david-k_25  A 15 minute walk across Lamar bridge over Lady...
# 5258         david-k_25  Walk down the hill to enjoy a cool swim in Aus...
# 5259         david-k_25  A short walk from the house is Zilker park, Au...
# 5260  dorothy-molencupp  This is a great little bar. You can sit outsid...
# 5261  dorothy-molencupp  This is a great shopping experience. If you do...
# 5262  dorothy-molencupp  Tuesday and Thursday are enchilada plate days....
# 5263  dorothy-molencupp  This is the go to after work place for dinner ...
# 5264  dorothy-molencupp  Great stuff and friendly staff. A great weeken...
# 5265  dorothy-molencupp  The food here was cold and prices are high. Th...
# 5266      rosemary-tsai  A good burger, but too over cooked. I think, i...
# 5267      rosemary-tsai  A good burger, but too over cooked. I think, i...
# 5268      rosemary-tsai  The only thing good about this hotel is their ...
# 5269       cindy-chow_2  Delicious food and great service! I had a pork...
# 5270       cindy-chow_2  The barbecue is delicious, especially the bris...
# 5271       cindy-chow_2  A very cute neighborhood with lots of cute ind...
# 5272       cindy-chow_2  A very convenient airport. The walk from the r...
# 5273       cindy-chow_2  An amazing sight to see so many bats streaming...
# 5274       cindy-chow_2  Good location, with rooms overlooking the rive...
# 5275         teresa-d_4  different, delicious twist on local tacos. sev...
# 5276         teresa-d_4                                            no text
# 5277         teresa-d_4                                            no text
# 5278         teresa-d_4                                            no text
# 5279         teresa-d_4  great local place for austin style tacos. nice...
# 5280         teresa-d_4  great local place for tasty and natural breakf...
# 5281         teresa-d_4  peacocks roam the park and trails. fantastic p...
# 5282         teresa-d_4  fantastic views of lake austin. walk up quite ...
# 5283         teresa-d_4  beautiful natural falls and hiking trails loca...
#
# [5284 rows x 5 columns]

# %%
df.dtypes
# Out:
# place_name     object
# category       object
# rating          int64
# user_name      object
# review_text    object
# dtype: object

# %% [markdown]
# # add user inputs into dataframe

# %%
def add_new_user(un='alex_nguyen', rt='no text'):
    rows_to_add = int(input("Enter the number of rows to add:"))

    for num in range(rows_to_add):
        places = input('Enter name of place: ')
        cat = input('Enter category Type: ')
        rat = input('Enter rating: ')
        #un = input('Enter username')
        #rt = input('Enter review')
        #df1 = pd.DataFrame(data=[[places,cat,rat, un, rt]],columns=['place_name', 'category', 'rating', 'user_name', 'review_text'])
        df1.loc[len(df1)] = [places,cat,rat, un, rt]
#     #df1 = add_new_user()
#     df = pd.concat([df,df1], axis=0)
#     df.index = range(len(df.index))
#     df['rating'] = df['rating'].astype(int)

# %%
df1 = pd.DataFrame(columns=['place_name', 'category', 'rating', 'user_name', 'review_text'])
add_new_user()
# Out:
# Enter the number of rows to add:2
# Enter name of place: Uchi
# Enter category Type: Restaurant
# Enter rating: 5
# Enter name of place: Zilker Metropolitan Park
# Enter category Type: Attraction
# Enter rating: 5

# %%
df1
# Out:
#                  place_name    category rating    user_name review_text
# 0                      Uchi  Restaurant      5  alex_nguyen     no text
# 1  Zilker Metropolitan Park  Attraction      5  alex_nguyen     no text

# %% [markdown]
# # Combine dataframes

# %%
df = pd.concat([df,df1], axis=0)
df.index = range(len(df.index))
df['rating'] = df['rating'].astype(int)

# %%
df.tail()
# Out:
#                              place_name    category  rating    user_name  \
# 5281  Mayfield Park and Nature Preserve  Attraction       5   teresa-d_4
# 5282                         Mt Bonnell  Attraction       5   teresa-d_4
# 5283          McKinney Falls State Park  Attraction       5   teresa-d_4
# 5284                               Uchi  Restaurant       5  alex_nguyen
# 5285           Zilker Metropolitan Park  Attraction       5  alex_nguyen
#
#                                             review_text
# 5281  peacocks roam the park and trails. fantastic p...
# 5282  fantastic views of lake austin. walk up quite ...
# 5283  beautiful natural falls and hiking trails loca...
# 5284                                            no text
# 5285                                            no text

# %%
df.pivot_table(values='rating', index ='place_name', columns = 'user_name')
# Out:
# user_name                                           alan-g_5  alex_nguyen  \
# place_name
#  Comics & More                                           NaN          NaN
# (512) Brewing Company                                    NaN          NaN
# ***Reduced! Heart of SXSW***; 3BR 2BA Downtown ...       NaN          NaN
# **SoCo BUNGALOW** Modern House Downtown, 3 bedr...       NaN          NaN
# 1 World of Tennis Sq Austin, TX  78738-1101 Uni...       NaN          NaN
# 1110 Carriage House Inn                                  NaN          NaN
# 15 Locks                                                 NaN          NaN
# 1886 Cafe & Bakery                                       NaN          NaN
# 24 Diner                                                 5.0          NaN
# 360 Bridge                                               NaN          NaN
# 360 Bridge Lookout                                       NaN          NaN
# 4th Tap Brewing Cooperative                              NaN          NaN
# 6th Street                                               5.0          NaN
# 800 Congress Ave                                         NaN          NaN
# 888 Pan Asian Restaurant                                 NaN          NaN
# A touch of Texas Hill Country in SOCO Austin, w...       NaN          NaN
# AISD Performing Arts Center                              NaN          NaN
# AMC Theatres Barton Creek Square 14                      NaN          NaN
# AT&T Executive Education and Conference Center           NaN          NaN
# ATX Hackerspace Co-Op                                    NaN          NaN
# Abel's On the Lake                                       NaN          NaN
# Ace Custom Tailors                                       NaN          NaN
# Adelbert's Brewery                                       NaN          NaN
# Agua Dulce Farm                                          NaN          NaN
# Ah Sing Den                                              NaN          NaN
# Alamo Drafthouse                                         NaN          NaN
# Alamo Drafthouse - South Lamar                           5.0          NaN
# Alamo Drafthouse Cinema                                  NaN          NaN
# Alamo Drafthouse Cinema Village                          NaN          NaN
# Alamo Drafthouse at The Ritz                             5.0          NaN
# ...                                                      ...          ...
# Yard Dog Gallery                                         NaN          NaN
# Yellow Jacket Social Club                                NaN          NaN
# Yo So Cool - Austin                                      NaN          NaN
# Yoga Yoga Northwest                                      NaN          NaN
# Yogurtland                                               NaN          NaN
# Yummy thai food                                          NaN          NaN
# Z'Tejas                                                  NaN          NaN
# ZACH Theater                                             NaN          NaN
# Zax Restaurant & Bar                                     NaN          NaN
# Zen Japanese Food Fast                                   NaN          NaN
# Zero Gravity Institute                                   NaN          NaN
# Zilker Botanical Garden                                  NaN          NaN
# Zilker Brewing Company and Taproom                       NaN          NaN
# Zilker Hillside Theater                                  NaN          NaN
# Zilker Metropolitan Park                                 5.0          5.0
# Zilker Park Boat Rentals                                 NaN          NaN
# Zilker Zephyr Miniature Train                            NaN          NaN
# Zocalo Cafe                                              NaN          NaN
# Zpizza                                                   NaN          NaN
# Zpizza Austin                                            NaN          NaN
# Zucchini Kill                                            NaN          NaN
# aloft Austin at the Domain                               NaN          NaN
# barre3 Austin                                            NaN          NaN
# grayDUCK Gallery                                         NaN          NaN
# iFLY Austin                                              NaN          NaN
# iPic Theaters                                            NaN          NaN
# method.hair                                              NaN          NaN
# milk + honey day spa                                     NaN          NaN
# pecan street festival                                    NaN          NaN
# projekt202                                               NaN          NaN
#
# user_name                                           alexandra-richmond  \
# place_name
#  Comics & More                                                     NaN
# (512) Brewing Company                                              NaN
# ***Reduced! Heart of SXSW***; 3BR 2BA Downtown ...                 NaN
# **SoCo BUNGALOW** Modern House Downtown, 3 bedr...                 NaN
# 1 World of Tennis Sq Austin, TX  78738-1101 Uni...                 NaN
# 1110 Carriage House Inn                                            NaN
# 15 Locks                                                           NaN
# 1886 Cafe & Bakery                                                 NaN
# 24 Diner                                                           NaN
# 360 Bridge                                                         NaN
# 360 Bridge Lookout                                                 NaN
# 4th Tap Brewing Cooperative                                        NaN
# 6th Street                                                         NaN
# 800 Congress Ave                                                   NaN
# 888 Pan Asian Restaurant                                           NaN
# A touch of Texas Hill Country in SOCO Austin, w...                 NaN
# AISD Performing Arts Center                                        NaN
# AMC Theatres Barton Creek Square 14                                NaN
# AT&T Executive Education and Conference Center                     NaN
# ATX Hackerspace Co-Op                                              NaN
# Abel's On the Lake                                                 NaN
# Ace Custom Tailors                                                 NaN
# Adelbert's Brewery                                                 NaN
# Agua Dulce Farm                                                    NaN
# Ah Sing Den                                                        NaN
# Alamo Drafthouse                                                   NaN
# Alamo Drafthouse - South Lamar                                     NaN
# Alamo Drafthouse Cinema                                            NaN
# Alamo Drafthouse Cinema Village                                    NaN
# Alamo Drafthouse at The Ritz                                       NaN
# ...                                                                ...
# Yard Dog Gallery                                                   NaN
# Yellow Jacket Social Club                                          NaN
# Yo So Cool - Austin                                                NaN
# Yoga Yoga Northwest                                                NaN
# Yogurtland                                                         NaN
# Yummy thai food                                                    NaN
# Z'Tejas                                                            NaN
# ZACH Theater                                                       NaN
# Zax Restaurant & Bar                                               NaN
# Zen Japanese Food Fast                                             NaN
# Zero Gravity Institute                                             NaN
# Zilker Botanical Garden                                            NaN
# Zilker Brewing Company and Taproom                                 NaN
# Zilker Hillside Theater                                            NaN
# Zilker Metropolitan Park                                           NaN
# Zilker Park Boat Rentals                                           NaN
# Zilker Zephyr Miniature Train                                      NaN
# Zocalo Cafe                                                        NaN
# Zpizza                                                             NaN
# Zpizza Austin                                                      NaN
# Zucchini Kill                                                      NaN
# aloft Austin at the Domain                                         NaN
# barre3 Austin                                                      NaN
# grayDUCK Gallery                                                   NaN
# iFLY Austin                                                        NaN
# iPic Theaters                                                      NaN
# method.hair                                                        NaN
# milk + honey day spa                                               NaN
# pecan street festival                                              NaN
# projekt202                                                         NaN
#
# user_name                                           alice-chase  \
# place_name
#  Comics & More                                              NaN
# (512) Brewing Company                                       NaN
# ***Reduced! Heart of SXSW***; 3BR 2BA Downtown ...          NaN
# **SoCo BUNGALOW** Modern House Downtown, 3 bedr...          NaN
# 1 World of Tennis Sq Austin, TX  78738-1101 Uni...          NaN
# 1110 Carriage House Inn                                     NaN
# 15 Locks                                                    NaN
# 1886 Cafe & Bakery                                          NaN
# 24 Diner                                                    NaN
# 360 Bridge                                                  NaN
# 360 Bridge Lookout                                          NaN
# 4th Tap Brewing Cooperative                                 NaN
# 6th Street                                                  NaN
# 800 Congress Ave                                            NaN
# 888 Pan Asian Restaurant                                    NaN
# A touch of Texas Hill Country in SOCO Austin, w...          NaN
# AISD Performing Arts Center                                 NaN
# AMC Theatres Barton Creek Square 14                         NaN
# AT&T Executive Education and Conference Center              NaN
# ATX Hackerspace Co-Op                                       NaN
# Abel's On the Lake                                          NaN
# Ace Custom Tailors                                          NaN
# Adelbert's Brewery                                          NaN
# Agua Dulce Farm                                             NaN
# Ah Sing Den                                                 NaN
# Alamo Drafthouse                                            5.0
# Alamo Drafthouse - South Lamar                              NaN
# Alamo Drafthouse Cinema                                     NaN
# Alamo Drafthouse Cinema Village                             NaN
# Alamo Drafthouse at The Ritz                                NaN
# ...                                                         ...
# Yard Dog Gallery                                            NaN
# Yellow Jacket Social Club                                   NaN
# Yo So Cool - Austin                                         NaN
# Yoga Yoga Northwest                                         NaN
# Yogurtland                                                  NaN
# Yummy thai food                                             NaN
# Z'Tejas                                                     NaN
# ZACH Theater                                                NaN
# Zax Restaurant & Bar                                        NaN
# Zen Japanese Food Fast                                      NaN
# Zero Gravity Institute                                      NaN
# Zilker Botanical Garden                                     NaN
# Zilker Brewing Company and Taproom                          NaN
# Zilker Hillside Theater                                     NaN
# Zilker Metropolitan Park                                    NaN
# Zilker Park Boat Rentals                                    NaN
# Zilker Zephyr Miniature Train                               NaN
# Zocalo Cafe                                                 NaN
# Zpizza                                                      NaN
# Zpizza Austin                                               NaN
# Zucchini Kill                                               NaN
# aloft Austin at the Domain                                  NaN
# barre3 Austin                                               NaN
# grayDUCK Gallery                                            NaN
# iFLY Austin                                                 NaN
# iPic Theaters                                               NaN
# method.hair                                                 NaN
# milk + honey day spa                                        NaN
# pecan street festival                                       NaN
# projekt202                                                  NaN
#
# user_name                                           alicia-moylan  allan-z  \
# place_name
#  Comics & More                                                NaN      NaN
# (512) Brewing Company                                         NaN      NaN
# ***Reduced! Heart of SXSW***; 3BR 2BA Downtown ...            NaN      NaN
# **SoCo BUNGALOW** Modern House Downtown, 3 bedr...            NaN      NaN
# 1 World of Tennis Sq Austin, TX  78738-1101 Uni...            NaN      NaN
# 1110 Carriage House Inn                                       NaN      NaN
# 15 Locks                                                      NaN      NaN
# 1886 Cafe & Bakery                                            NaN      NaN
# 24 Diner                                                      NaN      NaN
# 360 Bridge                                                    NaN      NaN
# 360 Bridge Lookout                                            NaN      NaN
# 4th Tap Brewing Cooperative                                   NaN      NaN
# 6th Street                                                    NaN      NaN
# 800 Congress Ave                                              NaN      NaN
# 888 Pan Asian Restaurant                                      NaN      NaN
# A touch of Texas Hill Country in SOCO Austin, w...            NaN      NaN
# AISD Performing Arts Center                                   NaN      NaN
# AMC Theatres Barton Creek Square 14                           NaN      NaN
# AT&T Executive Education and Conference Center                NaN      NaN
# ATX Hackerspace Co-Op                                         NaN      NaN
# Abel's On the Lake                                            NaN      NaN
# Ace Custom Tailors                                            NaN      NaN
# Adelbert's Brewery                                            NaN      NaN
# Agua Dulce Farm                                               NaN      NaN
# Ah Sing Den                                                   NaN      NaN
# Alamo Drafthouse                                              NaN      NaN
# Alamo Drafthouse - South Lamar                                5.0      NaN
# Alamo Drafthouse Cinema                                       NaN      NaN
# Alamo Drafthouse Cinema Village                               NaN      NaN
# Alamo Drafthouse at The Ritz                                  NaN      NaN
# ...                                                           ...      ...
# Yard Dog Gallery                                              NaN      NaN
# Yellow Jacket Social Club                                     NaN      NaN
# Yo So Cool - Austin                                           NaN      NaN
# Yoga Yoga Northwest                                           NaN      NaN
# Yogurtland                                                    NaN      NaN
# Yummy thai food                                               NaN      NaN
# Z'Tejas                                                       NaN      NaN
# ZACH Theater                                                  NaN      NaN
# Zax Restaurant & Bar                                          NaN      NaN
# Zen Japanese Food Fast                                        NaN      NaN
# Zero Gravity Institute                                        NaN      NaN
# Zilker Botanical Garden                                       5.0      NaN
# Zilker Brewing Company and Taproom                            NaN      NaN
# Zilker Hillside Theater                                       NaN      NaN
# Zilker Metropolitan Park                                      5.0      5.0
# Zilker Park Boat Rentals                                      NaN      NaN
# Zilker Zephyr Miniature Train                                 NaN      NaN
# Zocalo Cafe                                                   NaN      NaN
# Zpizza                                                        NaN      NaN
# Zpizza Austin                                                 NaN      NaN
# Zucchini Kill                                                 NaN      NaN
# aloft Austin at the Domain                                    NaN      NaN
# barre3 Austin                                                 NaN      NaN
# grayDUCK Gallery                                              NaN      NaN
# iFLY Austin                                                   NaN      NaN
# iPic Theaters                                                 NaN      NaN
# method.hair                                                   NaN      NaN
# milk + honey day spa                                          NaN      NaN
# pecan street festival                                         NaN      NaN
# projekt202                                                    NaN      NaN
#
# user_name                                           amit-anandwala  \
# place_name
#  Comics & More                                                 NaN
# (512) Brewing Company                                          NaN
# ***Reduced! Heart of SXSW***; 3BR 2BA Downtown ...             NaN
# **SoCo BUNGALOW** Modern House Downtown, 3 bedr...             NaN
# 1 World of Tennis Sq Austin, TX  78738-1101 Uni...             NaN
# 1110 Carriage House Inn                                        NaN
# 15 Locks                                                       NaN
# 1886 Cafe & Bakery                                             NaN
# 24 Diner                                                       NaN
# 360 Bridge                                                     NaN
# 360 Bridge Lookout                                             NaN
# 4th Tap Brewing Cooperative                                    NaN
# 6th Street                                                     NaN
# 800 Congress Ave                                               NaN
# 888 Pan Asian Restaurant                                       NaN
# A touch of Texas Hill Country in SOCO Austin, w...             NaN
# AISD Performing Arts Center                                    NaN
# AMC Theatres Barton Creek Square 14                            NaN
# AT&T Executive Education and Conference Center                 5.0
# ATX Hackerspace Co-Op                                          NaN
# Abel's On the Lake                                             NaN
# Ace Custom Tailors                                             NaN
# Adelbert's Brewery                                             NaN
# Agua Dulce Farm                                                NaN
# Ah Sing Den                                                    NaN
# Alamo Drafthouse                                               NaN
# Alamo Drafthouse - South Lamar                                 NaN
# Alamo Drafthouse Cinema                                        NaN
# Alamo Drafthouse Cinema Village                                NaN
# Alamo Drafthouse at The Ritz                                   NaN
# ...                                                            ...
# Yard Dog Gallery                                               NaN
# Yellow Jacket Social Club                                      NaN
# Yo So Cool - Austin                                            NaN
# Yoga Yoga Northwest                                            NaN
# Yogurtland                                                     NaN
# Yummy thai food                                                NaN
# Z'Tejas                                                        3.0
# ZACH Theater                                                   NaN
# Zax Restaurant & Bar                                           NaN
# Zen Japanese Food Fast                                         NaN
# Zero Gravity Institute                                         NaN
# Zilker Botanical Garden                                        NaN
# Zilker Brewing Company and Taproom                             NaN
# Zilker Hillside Theater                                        NaN
# Zilker Metropolitan Park                                       NaN
# Zilker Park Boat Rentals                                       NaN
# Zilker Zephyr Miniature Train                                  NaN
# Zocalo Cafe                                                    4.0
# Zpizza                                                         NaN
# Zpizza Austin                                                  NaN
# Zucchini Kill                                                  NaN
# aloft Austin at the Domain                                     NaN
# barre3 Austin                                                  NaN
# grayDUCK Gallery                                               NaN
# iFLY Austin                                                    NaN
# iPic Theaters                                                  NaN
# method.hair                                                    NaN
# milk + honey day spa                                           NaN
# pecan street festival                                          NaN
# projekt202                                                     NaN
#
# user_name                                           amy-simoes  andi-w  \
# place_name
#  Comics & More                                             NaN     NaN
# (512) Brewing Company                                      NaN     NaN
# ***Reduced! Heart of SXSW***; 3BR 2BA Downtown ...         NaN     NaN
# **SoCo BUNGALOW** Modern House Downtown, 3 bedr...         NaN     NaN
# 1 World of Tennis Sq Austin, TX  78738-1101 Uni...         NaN     NaN
# 1110 Carriage House Inn                                    NaN     NaN
# 15 Locks                                                   NaN     NaN
# 1886 Cafe & Bakery                                         NaN     NaN
# 24 Diner                                                   NaN     5.0
# 360 Bridge                                                 NaN     NaN
# 360 Bridge Lookout                                         NaN     NaN
# 4th Tap Brewing Cooperative                                NaN     NaN
# 6th Street                                                 5.0     NaN
# 800 Congress Ave                                           NaN     NaN
# 888 Pan Asian Restaurant                                   NaN     NaN
# A touch of Texas Hill Country in SOCO Austin, w...         NaN     NaN
# AISD Performing Arts Center                                NaN     NaN
# AMC Theatres Barton Creek Square 14                        NaN     NaN
# AT&T Executive Education and Conference Center             NaN     NaN
# ATX Hackerspace Co-Op                                      NaN     NaN
# Abel's On the Lake                                         NaN     NaN
# Ace Custom Tailors                                         NaN     NaN
# Adelbert's Brewery                                         NaN     NaN
# Agua Dulce Farm                                            NaN     NaN
# Ah Sing Den                                                NaN     NaN
# Alamo Drafthouse                                           NaN     NaN
# Alamo Drafthouse - South Lamar                             NaN     NaN
# Alamo Drafthouse Cinema                                    NaN     NaN
# Alamo Drafthouse Cinema Village                            NaN     NaN
# Alamo Drafthouse at The Ritz                               NaN     5.0
# ...                                                        ...     ...
# Yard Dog Gallery                                           NaN     NaN
# Yellow Jacket Social Club                                  NaN     NaN
# Yo So Cool - Austin                                        NaN     NaN
# Yoga Yoga Northwest                                        NaN     NaN
# Yogurtland                                                 NaN     NaN
# Yummy thai food                                            NaN     NaN
# Z'Tejas                                                    NaN     NaN
# ZACH Theater                                               NaN     NaN
# Zax Restaurant & Bar                                       NaN     NaN
# Zen Japanese Food Fast                                     NaN     NaN
# Zero Gravity Institute                                     NaN     NaN
# Zilker Botanical Garden                                    NaN     NaN
# Zilker Brewing Company and Taproom                         NaN     NaN
# Zilker Hillside Theater                                    NaN     NaN
# Zilker Metropolitan Park                                   5.0     4.0
# Zilker Park Boat Rentals                                   NaN     NaN
# Zilker Zephyr Miniature Train                              NaN     NaN
# Zocalo Cafe                                                NaN     NaN
# Zpizza                                                     NaN     NaN
# Zpizza Austin                                              NaN     NaN
# Zucchini Kill                                              NaN     NaN
# aloft Austin at the Domain                                 NaN     NaN
# barre3 Austin                                              NaN     NaN
# grayDUCK Gallery                                           NaN     NaN
# iFLY Austin                                                NaN     NaN
# iPic Theaters                                              NaN     NaN
# method.hair                                                NaN     NaN
# milk + honey day spa                                       NaN     NaN
# pecan street festival                                      NaN     NaN
# projekt202                                                 NaN     NaN
#
# user_name                                           andrew-w_3  \
# place_name
#  Comics & More                                             NaN
# (512) Brewing Company                                      NaN
# ***Reduced! Heart of SXSW***; 3BR 2BA Downtown ...         NaN
# **SoCo BUNGALOW** Modern House Downtown, 3 bedr...         NaN
# 1 World of Tennis Sq Austin, TX  78738-1101 Uni...         NaN
# 1110 Carriage House Inn                                    NaN
# 15 Locks                                                   NaN
# 1886 Cafe & Bakery                                         NaN
# 24 Diner                                                   NaN
# 360 Bridge                                                 NaN
# 360 Bridge Lookout                                         NaN
# 4th Tap Brewing Cooperative                                NaN
# 6th Street                                                 3.0
# 800 Congress Ave                                           NaN
# 888 Pan Asian Restaurant                                   NaN
# A touch of Texas Hill Country in SOCO Austin, w...         NaN
# AISD Performing Arts Center                                NaN
# AMC Theatres Barton Creek Square 14                        NaN
# AT&T Executive Education and Conference Center             NaN
# ATX Hackerspace Co-Op                                      NaN
# Abel's On the Lake                                         NaN
# Ace Custom Tailors                                         NaN
# Adelbert's Brewery                                         NaN
# Agua Dulce Farm                                            NaN
# Ah Sing Den                                                NaN
# Alamo Drafthouse                                           NaN
# Alamo Drafthouse - South Lamar                             NaN
# Alamo Drafthouse Cinema                                    NaN
# Alamo Drafthouse Cinema Village                            NaN
# Alamo Drafthouse at The Ritz                               NaN
# ...                                                        ...
# Yard Dog Gallery                                           NaN
# Yellow Jacket Social Club                                  NaN
# Yo So Cool - Austin                                        NaN
# Yoga Yoga Northwest                                        NaN
# Yogurtland                                                 NaN
# Yummy thai food                                            NaN
# Z'Tejas                                                    NaN
# ZACH Theater                                               NaN
# Zax Restaurant & Bar                                       NaN
# Zen Japanese Food Fast                                     NaN
# Zero Gravity Institute                                     NaN
# Zilker Botanical Garden                                    NaN
# Zilker Brewing Company and Taproom                         NaN
# Zilker Hillside Theater                                    NaN
# Zilker Metropolitan Park                                   5.0
# Zilker Park Boat Rentals                                   NaN
# Zilker Zephyr Miniature Train                              NaN
# Zocalo Cafe                                                NaN
# Zpizza                                                     NaN
# Zpizza Austin                                              NaN
# Zucchini Kill                                              NaN
# aloft Austin at the Domain                                 NaN
# barre3 Austin                                              NaN
# grayDUCK Gallery                                           NaN
# iFLY Austin                                                NaN
# iPic Theaters                                              NaN
# method.hair                                                NaN
# milk + honey day spa                                       NaN
# pecan street festival                                      NaN
# projekt202                                                 NaN
#
# user_name                                                ...         \
# place_name                                               ...
#  Comics & More                                           ...
# (512) Brewing Company                                    ...
# ***Reduced! Heart of SXSW***; 3BR 2BA Downtown ...       ...
# **SoCo BUNGALOW** Modern House Downtown, 3 bedr...       ...
# 1 World of Tennis Sq Austin, TX  78738-1101 Uni...       ...
# 1110 Carriage House Inn                                  ...
# 15 Locks                                                 ...
# 1886 Cafe & Bakery                                       ...
# 24 Diner                                                 ...
# 360 Bridge                                               ...
# 360 Bridge Lookout                                       ...
# 4th Tap Brewing Cooperative                              ...
# 6th Street                                               ...
# 800 Congress Ave                                         ...
# 888 Pan Asian Restaurant                                 ...
# A touch of Texas Hill Country in SOCO Austin, w...       ...
# AISD Performing Arts Center                              ...
# AMC Theatres Barton Creek Square 14                      ...
# AT&T Executive Education and Conference Center           ...
# ATX Hackerspace Co-Op                                    ...
# Abel's On the Lake                                       ...
# Ace Custom Tailors                                       ...
# Adelbert's Brewery                                       ...
# Agua Dulce Farm                                          ...
# Ah Sing Den                                              ...
# Alamo Drafthouse                                         ...
# Alamo Drafthouse - South Lamar                           ...
# Alamo Drafthouse Cinema                                  ...
# Alamo Drafthouse Cinema Village                          ...
# Alamo Drafthouse at The Ritz                             ...
# ...                                                      ...
# Yard Dog Gallery                                         ...
# Yellow Jacket Social Club                                ...
# Yo So Cool - Austin                                      ...
# Yoga Yoga Northwest                                      ...
# Yogurtland                                               ...
# Yummy thai food                                          ...
# Z'Tejas                                                  ...
# ZACH Theater                                             ...
# Zax Restaurant & Bar                                     ...
# Zen Japanese Food Fast                                   ...
# Zero Gravity Institute                                   ...
# Zilker Botanical Garden                                  ...
# Zilker Brewing Company and Taproom                       ...
# Zilker Hillside Theater                                  ...
# Zilker Metropolitan Park                                 ...
# Zilker Park Boat Rentals                                 ...
# Zilker Zephyr Miniature Train                            ...
# Zocalo Cafe                                              ...
# Zpizza                                                   ...
# Zpizza Austin                                            ...
# Zucchini Kill                                            ...
# aloft Austin at the Domain                               ...
# barre3 Austin                                            ...
# grayDUCK Gallery                                         ...
# iFLY Austin                                              ...
# iPic Theaters                                            ...
# method.hair                                              ...
# milk + honey day spa                                     ...
# pecan street festival                                    ...
# projekt202                                               ...
#
# user_name                                           travis-katz  trinidad-m_2  \
# place_name
#  Comics & More                                              NaN           NaN
# (512) Brewing Company                                       NaN           NaN
# ***Reduced! Heart of SXSW***; 3BR 2BA Downtown ...          NaN           NaN
# **SoCo BUNGALOW** Modern House Downtown, 3 bedr...          NaN           NaN
# 1 World of Tennis Sq Austin, TX  78738-1101 Uni...          NaN           NaN
# 1110 Carriage House Inn                                     NaN           NaN
# 15 Locks                                                    NaN           NaN
# 1886 Cafe & Bakery                                          4.0           NaN
# 24 Diner                                                    4.0           NaN
# 360 Bridge                                                  NaN           NaN
# 360 Bridge Lookout                                          NaN           NaN
# 4th Tap Brewing Cooperative                                 NaN           NaN
# 6th Street                                                  NaN           5.0
# 800 Congress Ave                                            NaN           NaN
# 888 Pan Asian Restaurant                                    NaN           NaN
# A touch of Texas Hill Country in SOCO Austin, w...          NaN           NaN
# AISD Performing Arts Center                                 NaN           NaN
# AMC Theatres Barton Creek Square 14                         NaN           NaN
# AT&T Executive Education and Conference Center              NaN           NaN
# ATX Hackerspace Co-Op                                       NaN           NaN
# Abel's On the Lake                                          NaN           NaN
# Ace Custom Tailors                                          NaN           NaN
# Adelbert's Brewery                                          NaN           NaN
# Agua Dulce Farm                                             NaN           NaN
# Ah Sing Den                                                 NaN           NaN
# Alamo Drafthouse                                            NaN           NaN
# Alamo Drafthouse - South Lamar                              NaN           NaN
# Alamo Drafthouse Cinema                                     NaN           NaN
# Alamo Drafthouse Cinema Village                             NaN           NaN
# Alamo Drafthouse at The Ritz                                NaN           NaN
# ...                                                         ...           ...
# Yard Dog Gallery                                            NaN           NaN
# Yellow Jacket Social Club                                   NaN           NaN
# Yo So Cool - Austin                                         NaN           NaN
# Yoga Yoga Northwest                                         NaN           NaN
# Yogurtland                                                  NaN           NaN
# Yummy thai food                                             NaN           NaN
# Z'Tejas                                                     NaN           NaN
# ZACH Theater                                                NaN           NaN
# Zax Restaurant & Bar                                        NaN           NaN
# Zen Japanese Food Fast                                      NaN           NaN
# Zero Gravity Institute                                      NaN           NaN
# Zilker Botanical Garden                                     NaN           NaN
# Zilker Brewing Company and Taproom                          NaN           NaN
# Zilker Hillside Theater                                     NaN           NaN
# Zilker Metropolitan Park                                    NaN           5.0
# Zilker Park Boat Rentals                                    NaN           NaN
# Zilker Zephyr Miniature Train                               NaN           NaN
# Zocalo Cafe                                                 NaN           NaN
# Zpizza                                                      NaN           NaN
# Zpizza Austin                                               NaN           NaN
# Zucchini Kill                                               NaN           NaN
# aloft Austin at the Domain                                  NaN           NaN
# barre3 Austin                                               NaN           NaN
# grayDUCK Gallery                                            NaN           NaN
# iFLY Austin                                                 NaN           NaN
# iPic Theaters                                               NaN           NaN
# method.hair                                                 NaN           NaN
# milk + honey day spa                                        NaN           NaN
# pecan street festival                                       NaN           NaN
# projekt202                                                  NaN           NaN
#
# user_name                                           tyson-bramer  van-le  \
# place_name
#  Comics & More                                               NaN     NaN
# (512) Brewing Company                                        NaN     NaN
# ***Reduced! Heart of SXSW***; 3BR 2BA Downtown ...           NaN     NaN
# **SoCo BUNGALOW** Modern House Downtown, 3 bedr...           NaN     NaN
# 1 World of Tennis Sq Austin, TX  78738-1101 Uni...           NaN     NaN
# 1110 Carriage House Inn                                      NaN     NaN
# 15 Locks                                                     NaN     NaN
# 1886 Cafe & Bakery                                           NaN     NaN
# 24 Diner                                                     NaN     5.0
# 360 Bridge                                                   NaN     NaN
# 360 Bridge Lookout                                           NaN     NaN
# 4th Tap Brewing Cooperative                                  NaN     NaN
# 6th Street                                                   4.0     4.0
# 800 Congress Ave                                             NaN     NaN
# 888 Pan Asian Restaurant                                     NaN     NaN
# A touch of Texas Hill Country in SOCO Austin, w...           NaN     NaN
# AISD Performing Arts Center                                  NaN     NaN
# AMC Theatres Barton Creek Square 14                          NaN     NaN
# AT&T Executive Education and Conference Center               NaN     NaN
# ATX Hackerspace Co-Op                                        NaN     NaN
# Abel's On the Lake                                           NaN     4.0
# Ace Custom Tailors                                           NaN     NaN
# Adelbert's Brewery                                           NaN     NaN
# Agua Dulce Farm                                              NaN     NaN
# Ah Sing Den                                                  NaN     NaN
# Alamo Drafthouse                                             NaN     NaN
# Alamo Drafthouse - South Lamar                               NaN     5.0
# Alamo Drafthouse Cinema                                      NaN     NaN
# Alamo Drafthouse Cinema Village                              NaN     NaN
# Alamo Drafthouse at The Ritz                                 NaN     NaN
# ...                                                          ...     ...
# Yard Dog Gallery                                             NaN     NaN
# Yellow Jacket Social Club                                    NaN     NaN
# Yo So Cool - Austin                                          NaN     NaN
# Yoga Yoga Northwest                                          NaN     NaN
# Yogurtland                                                   NaN     NaN
# Yummy thai food                                              NaN     NaN
# Z'Tejas                                                      NaN     NaN
# ZACH Theater                                                 NaN     NaN
# Zax Restaurant & Bar                                         NaN     NaN
# Zen Japanese Food Fast                                       NaN     NaN
# Zero Gravity Institute                                       NaN     NaN
# Zilker Botanical Garden                                      NaN     NaN
# Zilker Brewing Company and Taproom                           NaN     NaN
# Zilker Hillside Theater                                      NaN     NaN
# Zilker Metropolitan Park                                     5.0     NaN
# Zilker Park Boat Rentals                                     NaN     NaN
# Zilker Zephyr Miniature Train                                NaN     NaN
# Zocalo Cafe                                                  NaN     NaN
# Zpizza                                                       NaN     NaN
# Zpizza Austin                                                NaN     NaN
# Zucchini Kill                                                NaN     NaN
# aloft Austin at the Domain                                   NaN     NaN
# barre3 Austin                                                NaN     NaN
# grayDUCK Gallery                                             NaN     NaN
# iFLY Austin                                                  NaN     NaN
# iPic Theaters                                                NaN     NaN
# method.hair                                                  NaN     NaN
# milk + honey day spa                                         NaN     NaN
# pecan street festival                                        NaN     NaN
# projekt202                                                   NaN     NaN
#
# user_name                                           vicki-t  vivian-c  \
# place_name
#  Comics & More                                          NaN       NaN
# (512) Brewing Company                                   NaN       NaN
# ***Reduced! Heart of SXSW***; 3BR 2BA Downtown ...      NaN       NaN
# **SoCo BUNGALOW** Modern House Downtown, 3 bedr...      NaN       NaN
# 1 World of Tennis Sq Austin, TX  78738-1101 Uni...      NaN       NaN
# 1110 Carriage House Inn                                 NaN       NaN
# 15 Locks                                                NaN       NaN
# 1886 Cafe & Bakery                                      NaN       NaN
# 24 Diner                                                NaN       NaN
# 360 Bridge                                              NaN       NaN
# 360 Bridge Lookout                                      NaN       NaN
# 4th Tap Brewing Cooperative                             NaN       NaN
# 6th Street                                              4.0       NaN
# 800 Congress Ave                                        NaN       NaN
# 888 Pan Asian Restaurant                                NaN       NaN
# A touch of Texas Hill Country in SOCO Austin, w...      NaN       NaN
# AISD Performing Arts Center                             NaN       NaN
# AMC Theatres Barton Creek Square 14                     NaN       NaN
# AT&T Executive Education and Conference Center          NaN       NaN
# ATX Hackerspace Co-Op                                   NaN       NaN
# Abel's On the Lake                                      NaN       NaN
# ...
# ATX Hackerspace Co-Op                                           NaN
# Abel's On the Lake                                              NaN
# Ace Custom Tailors                                              NaN
# Adelbert's Brewery                                              NaN
# Agua Dulce Farm                                                 NaN
# Ah Sing Den                                                     NaN
# Alamo Drafthouse                                                NaN
# Alamo Drafthouse - South Lamar                                  NaN
# Alamo Drafthouse Cinema                                         NaN
# Alamo Drafthouse Cinema Village                                 NaN
# Alamo Drafthouse at The Ritz                                    NaN
# ...                                                             ...
# Yard Dog Gallery                                                NaN
# Yellow Jacket Social Club                                       NaN
# Yo So Cool - Austin                                             NaN
# Yoga Yoga Northwest                                             NaN
# Yogurtland                                                      NaN
# Yummy thai food                                                 NaN
# Z'Tejas                                                         NaN
# ZACH Theater                                                    NaN
# Zax Restaurant & Bar                                            NaN
# Zen Japanese Food Fast                                          NaN
# Zero Gravity Institute                                          NaN
# Zilker Botanical Garden                                         NaN
# Zilker Brewing Company and Taproom                              NaN
# Zilker Hillside Theater                                         NaN
# Zilker Metropolitan Park                                        NaN
# Zilker Park Boat Rentals                                        NaN
# Zilker Zephyr Miniature Train                                   NaN
# Zocalo Cafe                                                     NaN
# Zpizza                                                          NaN
# Zpizza Austin                                                   NaN
# Zucchini Kill                                                   NaN
# aloft Austin at the Domain                                      NaN
# barre3 Austin                                                   NaN
# grayDUCK Gallery                                                NaN
# iFLY Austin                                                     NaN
# iPic Theaters                                                   NaN
# method.hair                                                     NaN
# milk + honey day spa                                            NaN
# pecan street festival                                           NaN
# projekt202                                                      NaN
#
# user_name                                           wendy-p_6  \
# place_name
#  Comics & More                                            NaN
# (512) Brewing Company                                     NaN
# ***Reduced! Heart of SXSW***; 3BR 2BA Downtown ...        NaN
# **SoCo BUNGALOW** Modern House Downtown, 3 bedr...        NaN
# 1 World of Tennis Sq Austin, TX  78738-1101 Uni...        NaN
# 1110 Carriage House Inn                                   NaN
# 15 Locks                                                  NaN
# 1886 Cafe & Bakery                                        NaN
# 24 Diner                                                  NaN
# 360 Bridge                                                NaN
# 360 Bridge Lookout                                        NaN
# 4th Tap Brewing Cooperative                               NaN
# 6th Street                                                NaN
# 800 Congress Ave                                          NaN
# 888 Pan Asian Restaurant                                  NaN
# A touch of Texas Hill Country in SOCO Austin, w...        NaN
# AISD Performing Arts Center                               NaN
# AMC Theatres Barton Creek Square 14                       NaN
# AT&T Executive Education and Conference Center            NaN
# ATX Hackerspace Co-Op                                     NaN
# Abel's On the Lake                                        NaN
# Ace Custom Tailors                                        NaN
# Adelbert's Brewery                                        NaN
# Agua Dulce Farm                                           NaN
# Ah Sing Den                                               NaN
# Alamo Drafthouse                                          NaN
# Alamo Drafthouse - South Lamar                            NaN
# Alamo Drafthouse Cinema                                   NaN
# Alamo Drafthouse Cinema Village                           NaN
# Alamo Drafthouse at The Ritz                              NaN
# ...                                                       ...
# Yard Dog Gallery                                          NaN
# Yellow Jacket Social Club                                 NaN
# Yo So Cool - Austin                                       NaN
# Yoga Yoga Northwest                                       NaN
# Yogurtland                                                NaN
# Yummy thai food                                           NaN
# Z'Tejas                                                   NaN
# ZACH Theater                                              NaN
# Zax Restaurant & Bar                                      NaN
# Zen Japanese Food Fast                                    NaN
# Zero Gravity Institute                                    NaN
# Zilker Botanical Garden                                   NaN
# Zilker Brewing Company and Taproom                        NaN
# Zilker Hillside Theater                                   NaN
# Zilker Metropolitan Park                                  5.0
# Zilker Park Boat Rentals                                  NaN
# Zilker Zephyr Miniature Train                             NaN
# Zocalo Cafe                                               NaN
# Zpizza                                                    NaN
# Zpizza Austin                                             NaN
# Zucchini Kill                                             NaN
# aloft Austin at the Domain                                NaN
# barre3 Austin                                             NaN
# grayDUCK Gallery                                          NaN
# iFLY Austin                                               NaN
# iPic Theaters                                             NaN
# method.hair                                               NaN
# milk + honey day spa                                      NaN
# pecan street festival                                     NaN
# projekt202                                                NaN
#
# user_name                                           what-moms-think  \
# place_name
#  Comics & More                                                  NaN
# (512) Brewing Company                                           NaN
# ***Reduced! Heart of SXSW***; 3BR 2BA Downtown ...              NaN
# **SoCo BUNGALOW** Modern House Downtown, 3 bedr...              NaN
# 1 World of Tennis Sq Austin, TX  78738-1101 Uni...              3.0
# 1110 Carriage House Inn                                         NaN
# 15 Locks                                                        NaN
# 1886 Cafe & Bakery                                              NaN
# 24 Diner                                                        NaN
# 360 Bridge                                                      5.0
# 360 Bridge Lookout                                              5.0
# 4th Tap Brewing Cooperative                                     NaN
# 6th Street                                                      NaN
# 800 Congress Ave                                                NaN
# 888 Pan Asian Restaurant                                        NaN
# A touch of Texas Hill Country in SOCO Austin, w...              NaN
# AISD Performing Arts Center                                     NaN
# AMC Theatres Barton Creek Square 14                             NaN
# AT&T Executive Education and Conference Center                  NaN
# ATX Hackerspace Co-Op                                           NaN
# Abel's On the Lake                                              NaN
# Ace Custom Tailors                                              NaN
# Adelbert's Brewery                                              NaN
# Agua Dulce Farm                                                 NaN
# Ah Sing Den                                                     NaN
# Alamo Drafthouse                                                NaN
# Alamo Drafthouse - South Lamar                                  NaN
# Alamo Drafthouse Cinema                                         NaN
# Alamo Drafthouse Cinema Village                                 NaN
# Alamo Drafthouse at The Ritz                                    NaN
# ...                                                             ...
# Yard Dog Gallery                                                NaN
# Yellow Jacket Social Club                                       NaN
# Yo So Cool - Austin                                             NaN
# Yoga Yoga Northwest                                             NaN
# Yogurtland                                                      NaN
# Yummy thai food                                                 NaN
# Z'Tejas                                                         NaN
# ZACH Theater                                                    NaN
# Zax Restaurant & Bar                                            NaN
# Zen Japanese Food Fast                                          NaN
# Zero Gravity Institute                                          NaN
# Zilker Botanical Garden                                         5.0
# Zilker Brewing Company and Taproom                              NaN
# Zilker Hillside Theater                                         5.0
# Zilker Metropolitan Park                                        5.0
# Zilker Park Boat Rentals                                        NaN
# Zilker Zephyr Miniature Train                                   NaN
# Zocalo Cafe                                                     NaN
# Zpizza                                                          NaN
# Zpizza Austin                                                   NaN
# Zucchini Kill                                                   NaN
# aloft Austin at the Domain                                      NaN
# barre3 Austin                                                   5.0
# grayDUCK Gallery                                                NaN
# iFLY Austin                                                     NaN
# iPic Theaters                                                   NaN
# method.hair                                                     NaN
# milk + honey day spa                                            NaN
# pecan street festival                                           NaN
# projekt202                                                      NaN
#
# user_name                                           yelena-konetchy
# place_name
#  Comics & More                                                  NaN
# (512) Brewing Company                                           NaN
# ***Reduced! Heart of SXSW***; 3BR 2BA Downtown ...              NaN
# **SoCo BUNGALOW** Modern House Downtown, 3 bedr...              NaN
# 1 World of Tennis Sq Austin, TX  78738-1101 Uni...              NaN
# 1110 Carriage House Inn                                         NaN
# 15 Locks                                                        NaN
# 1886 Cafe & Bakery                                              NaN
# 24 Diner                                                        NaN
# 360 Bridge                                                      NaN
# 360 Bridge Lookout                                              NaN
# 4th Tap Brewing Cooperative                                     NaN
# 6th Street                                                      NaN
# 800 Congress Ave                                                NaN
# 888 Pan Asian Restaurant                                        NaN
# A touch of Texas Hill Country in SOCO Austin, w...              NaN
# AISD Performing Arts Center                                     NaN
# AMC Theatres Barton Creek Square 14                             NaN
# AT&T Executive Education and Conference Center                  NaN
# ATX Hackerspace Co-Op                                           NaN
# Abel's On the Lake                                              NaN
# Ace Custom Tailors                                              NaN
# Adelbert's Brewery                                              NaN
# Agua Dulce Farm                                                 NaN
# Ah Sing Den                                                     NaN
# Alamo Drafthouse                                                NaN
# Alamo Drafthouse - South Lamar                                  NaN
# Alamo Drafthouse Cinema                                         NaN
# Alamo Drafthouse Cinema Village                                 NaN
# Alamo Drafthouse at The Ritz                                    NaN
# ...                                                             ...
# Yard Dog Gallery                                                NaN
# Yellow Jacket Social Club                                       NaN
# Yo So Cool - Austin                                             NaN
# Yoga Yoga Northwest                                             NaN
# Yogurtland                                                      NaN
# Yummy thai food                                                 NaN
# Z'Tejas                                                         NaN
# ZACH Theater                                                    NaN
# Zax Restaurant & Bar                                            NaN
# Zen Japanese Food Fast                                          NaN
# Zero Gravity Institute                                          NaN
# Zilker Botanical Garden                                         NaN
# Zilker Brewing Company and Taproom                              NaN
# Zilker Hillside Theater                                         NaN
# Zilker Metropolitan Park                                        NaN
# Zilker Park Boat Rentals                                        NaN
# Zilker Zephyr Miniature Train                                   NaN
# Zocalo Cafe                                                     NaN
# Zpizza                                                          NaN
# Zpizza Austin                                                   NaN
# Zucchini Kill                                                   NaN
# aloft Austin at the Domain                                      3.0
# barre3 Austin                                                   NaN
# grayDUCK Gallery                                                NaN
# iFLY Austin                                                     NaN
# iPic Theaters                                                   NaN
# method.hair                                                     3.0
# milk + honey day spa                                            NaN
# pecan street festival                                           NaN
# projekt202                                                      NaN
#
# [1596 rows x 198 columns]

# %% [markdown]
# # create separate dataframes for places and users after applying cosine similarity

# %%
# create pivot tables
places_pivot = df.pivot_table(values='rating', index ='place_name', columns = 'user_name')
user_pivot = df.pivot_table(values='rating', index ='place_name', columns = 'user_name').T

# create sparse matrixes
places_sparse = sparse.csr_matrix(places_pivot.fillna(0))
user_sparse = sparse.csr_matrix(user_pivot.fillna(0))

# create pairwise distances
places_recommender = pairwise_distances(places_sparse, metric='cosine')
user_recommender = pairwise_distances(user_sparse, metric='cosine')

# create dataframes after performing pairwise distance using cosine similarity
places_recommender_df = pd.DataFrame(places_recommender, index=places_pivot.index, columns=places_pivot.index)
user_recommender_df = pd.DataFrame(user_recommender, index=user_pivot.index, columns=user_pivot.index)

# %% [markdown]
# # Recommender functions:
# - similar places
# - similar users
# - combined

# %%
def place_recommender(places_recommender_df):
    search = input("Enter the name of place\n")
    print('')
    try:
        for place in df[df['place_name'].str.contains(search)]['place_name']:
            print('Average Rating', round(df[df['place_name'] == place]['rating'].mean(),4))
            print('Number of Rating', df[df['place_name'] == place].shape[0])
            print('')
            print('Recommendations')
            display(places_recommender_df[place].sort_values()[1:11])
            print('')
    except:
        print("Please check the place name")

# %%
def user_recommender():
    search = input("Enter username\n")
    print ('')
    try:
        for name in df[df['user_name'].str.contains(search)]['user_name']:
            print('Average Rating', round(df[df['user_name'] == name]['rating'].mean(),4))
            print('Number of Reviews', df[df['user_name'] == name].shape[0])
            print('')
            print('Recommendations')
            display(user_recommender_df[name].sort_values()[1:11])
            print('')
    except:
        print("Please check the username")

# %%
def recommender(places_recommender_df, user_recommender_df):
    while True:
        Query = input("\nSelect one or type 'done' to quit:\n 1) Recommendations for similar users \n 2) Recommendations for similar places\n")
        if Query == '1':
            try:
                user_recommender()
            except:
                os.system('clear')
                print("Please check the username")

        elif Query == '2':
            try:
                place_recommender()

            except:
                print("please check the place name")

        elif Query == 'done':

            break

        else:
            print("please try again")

# %%
recommender(places_recommender_df, user_recommender_df)
# Out:
# Select one or type 'done' to quit:
#  1) Recommendations for similar users
#  2) Recommendations for similar places
# 1
# Enter username
# alex_nguyen
#
# Average Rating 5.0
# Number of Reviews 2
#
# Recommendations
# user_name
# angie-m_9        0.532731
# david-k_25       0.539520
# shelby-s         0.628846
# ashley-d         0.646888
# satish-talim     0.661357
# trinidad-m_2     0.696551
# holly-w_4        0.699035
# kathleen-r_13    0.702632
# richard-james    0.709381
# shonda           0.711325
# Name: alex_nguyen, dtype: float64
# Average Rating 5.0
# Number of Reviews 2
#
# Recommendations
# user_name
# angie-m_9        0.532731
# david-k_25       0.539520
# shelby-s         0.628846
# ashley-d         0.646888
# satish-talim     0.661357
# trinidad-m_2     0.696551
# holly-w_4        0.699035
# kathleen-r_13    0.702632
# richard-james    0.709381
# shonda           0.711325
# Name: alex_nguyen, dtype: float64
# Select one or type 'done' to quit:
#  1) Recommendations for similar users
#  2) Recommendations for similar places
# done

# %%
df[df['user_name'] == 'shonda'].head(20)
# Out:
#                     place_name    category  rating user_name review_text
# 4671             Rainey Street  Attraction       5    shonda     no text
# 4672         Franklin Barbecue  Restaurant       5    shonda     no text
# 4673                6th Street  Attraction       5    shonda     no text
# 4674       Texas State Capitol  Attraction       5    shonda     no text
# 4675  Zilker Metropolitan Park  Attraction       5    shonda     no text
# 4676       Barton Springs Pool  Attraction       5    shonda     no text

# %% [markdown]
# # Example of top recommendations for a place

# %%
places_recommender_df['Uchi'] # has to be exact name of the place
# Out:
# place_name
#  Comics & More                                                                      1.000000
# (512) Brewing Company                                                               1.000000
# ***Reduced! Heart of SXSW***; 3BR 2BA Downtown Home Easy Walk to Most Everything    1.000000
# **SoCo BUNGALOW** Modern House Downtown, 3 bedroom/2 bath, sleeps 8                 0.784635
# 1 World of Tennis Sq Austin, TX  78738-1101 United States                           1.000000
# 1110 Carriage House Inn                                                             1.000000
# 15 Locks                                                                            1.000000
# 1886 Cafe & Bakery                                                                  0.873967
# 24 Diner                                                                            0.769078
# 360 Bridge                                                                          1.000000
# 360 Bridge Lookout                                                                  0.903686
# 4th Tap Brewing Cooperative                                                         1.000000
# 6th Street                                                                          0.740982
# 800 Congress Ave                                                                    1.000000
# 888 Pan Asian Restaurant                                                            0.883883
# A touch of Texas Hill Country in SOCO Austin, w/JACUZZI                             1.000000
# AISD Performing Arts Center                                                         1.000000
# AMC Theatres Barton Creek Square 14                                                 1.000000
# AT&T Executive Education and Conference Center                                      0.893961
# ATX Hackerspace Co-Op                                                               1.000000
# Abel's On the Lake                                                                  1.000000
# Ace Custom Tailors                                                                  1.000000
# Adelbert's Brewery                                                                  1.000000
# Agua Dulce Farm                                                                     1.000000
# Ah Sing Den                                                                         1.000000
# Alamo Drafthouse                                                                    0.784024
# Alamo Drafthouse - South Lamar                                                      0.567075
# Alamo Drafthouse Cinema                                                             0.847714
# Alamo Drafthouse Cinema Village                                                     0.906274
# Alamo Drafthouse at The Ritz                                                        0.725053
#                                                                                       ...
# Yard Dog Gallery                                                                    0.734904
# Yellow Jacket Social Club                                                           1.000000
# Yo So Cool - Austin                                                                 1.000000
# Yoga Yoga Northwest                                                                 0.784635
# Yogurtland                                                                          1.000000
# Yummy thai food                                                                     1.000000
# Z'Tejas                                                                             0.787139
# ZACH Theater                                                                        1.000000
# Zax Restaurant & Bar                                                                0.784635
# Zen Japanese Food Fast                                                              0.784635
# Zero Gravity Institute                                                              0.784635
# Zilker Botanical Garden                                                             0.781939
# Zilker Brewing Company and Taproom                                                  1.000000
# Zilker Hillside Theater                                                             0.847714
# Zilker Metropolitan Park                                                            0.591999
# Zilker Park Boat Rentals                                                            1.000000
# Zilker Zephyr Miniature Train                                                       0.882770
# Zocalo Cafe                                                                         1.000000
# Zpizza                                                                              0.784635
# Zpizza Austin                                                                       0.784635
# Zucchini Kill                                                                       0.784635
# aloft Austin at the Domain                                                          1.000000
# barre3 Austin                                                                       1.000000
# grayDUCK Gallery                                                                    1.000000
# iFLY Austin                                                                         0.892317
# iPic Theaters                                                                       1.000000
# method.hair                                                                         1.000000
# milk + honey day spa                                                                0.784635
# pecan street festival                                                               1.000000
# projekt202                                                                          1.000000
# Name: Uchi, Length: 1596, dtype: float64

# %% [markdown]
# ## Plotly

# %%
# cf.go_offline()
# # Set the global them 
# cf.set_config_file(world_readable=True, theme='pearl', offline=True)

# %%
# df.pivot(columns='place_name',values='rating').iplot(kind='scatter',xTitle='Places',yTitle='Ratings')

# %%
# trace0 = go.Scatter(x=df['place_name'],y=df['rating'],name='Places')
# trace1 = go.Scatter(x=df['user_name'], y=df['rating'],name='Users')

# %%
# trace1 = go.Scatter(x=df['user_name'], y=df['rating'],name='Users',
#     mode = 'markers', 
#     marker = dict(
#         color = '#FFBAD2',
#         line = dict(width = 1)
#     )
# )
# data = [trace1]

# py.iplot(data)

# %%
# df['rating'].mean()

# %%
# trace0 = go.Histogram(
#     x=df['user_name'], y=df['rating'].mean(),name='Users'
# )
# trace1 = go.Histogram(
#     x=df['place_name'],y=df['rating'].mean(),name='Places'
# )
# data = [trace0, trace1]
# layout = go.Layout(barmode='stack')
# fig = go.Figure(data=data, layout=layout)

# py.iplot(fig)

# %%
# trace1 = go.Scatter(x=df['user_name'], y=df['rating'],name='Users',
#     mode='markers',
#     marker=dict(
#         size=16,
#         color = np.random.randn(6000), #set color equal to a variable
#         colorscale='Viridis',
#         showscale=True
#     )
# )
# data = [trace1]

# py.iplot(data)

# %%
# data = [trace0,trace1]
# #layout = go.Layout(barmode='group')

# fig = go.Figure(data=data, layout=layout)
# py.iplot(fig)
# py.iplot(fig, filename='grouped-bar')

# %%
# df.iplot(kind='scatter',title='Ratings of Places',xTitle='Places',yTitle='Ratings')

# %%
# df.iplot(kind='hist',title='Ratings of Places',xTitle='Ratings',yTitle='Places')
