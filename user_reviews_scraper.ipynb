# %% [markdown]
# # Scraper for user reviews
# - [Trip by skyscanner website](https://www.trip.skyscanner.com/leaderboard/region/2000000000399)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Scraper-for-user-reviews" data-toc-modified-id="Scraper-for-user-reviews-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Scraper for user reviews</a></span></li><li><span><a href="#Import-Modules-and-packages" data-toc-modified-id="Import-Modules-and-packages-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import Modules and packages</a></span><ul class="toc-item"><li><span><a href="#Load-in-.csv-file-of-top-200-users" data-toc-modified-id="Load-in-.csv-file-of-top-200-users-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Load in .csv file of top 200 users</a></span></li></ul></li><li><span><a href="#Define-scraping-function-to-loop-through-urls" data-toc-modified-id="Define-scraping-function-to-loop-through-urls-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Define scraping function to loop through urls</a></span></li><li><span><a href="#Use-scraper-function-to-loop-through-urls" data-toc-modified-id="Use-scraper-function-to-loop-through-urls-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Use scraper function to loop through urls</a></span></li><li><span><a href="#Save-dataframe-to-csv" data-toc-modified-id="Save-dataframe-to-csv-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Save dataframe to csv</a></span></li></ul></div>

# %% [markdown]
# # Import Modules and packages

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
from time import sleep 
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait

# %% [markdown]
# ## Load in .csv file of top 200 users

# %%
user_name_df = pd.read_csv('./atx_leaderboards_top200.csv', index_col=0)
user_name_list = user_name_df['id'].tolist()

# %%
user_name_list[0:50] # view first 50 usernames
# Out:
# ['what-moms-think',
#  'yelena-konetchy',
#  'bailey-k_2',
#  'ramona-flume',
#  'patty-drew',
#  'nina-pena_2',
#  'tiffany-z',
#  'meg-brooker',
#  'brent-wistrom',
#  'stephanie-asmus',
#  'amit-anandwala',
#  'mark-payne_3',
#  'melody-lowe',
#  'elisa-regulski',
#  'ryan-onyxhotels',
#  'stephen-andears',
#  'alice-chase',
#  'mary-beth-c_2',
#  'justine_14',
#  'jen-knoedl',
#  'travis-katz',
#  'broke-girls-guide',
#  'mary-lou-t_2',
#  'persis-ratouis',
#  'laraye-rushing',
#  'netta-drimer_2',
#  'paula_19',
#  'diane-austin',
#  'suzanne-wyble',
#  'audrey-lo-travelingaudrey_2',
#  'libby_3',
#  'connie-chang',
#  'patrick-keltner',
#  'van-le',
#  'baxter-jackson',
#  'steve-deangelo',
#  'susan-l_19',
#  'jessica-abramson',
#  'alicia-moylan',
#  'nina-h_3',
#  'keane',
#  'derrick-sison',
#  'deborah-peacock_2',
#  'rebecca-goglia-beccabandit',
#  'rie_4',
#  'frances-nguyen-ha',
#  'dale-c_3',
#  'april-mccormick-miner',
#  'katherine_9',
#  'gmack']

# %%
base = 'https://www.trip.skyscanner.com/user/' # base url
user_id = user_name_list[0]                    # starting username
passport = '/passport/austin'                  # remainder of url
url = base+user_id+passport                    # combined url

# %%
url
# Out:
# 'https://www.trip.skyscanner.com/user/what-moms-think/passport/austin'

# %%
# create list of urls to loop through
urls = []              
for name in user_name_list:
    urls.append(base+name+passport)
urls
# Out:
# ['https://www.trip.skyscanner.com/user/what-moms-think/passport/austin',
#  'https://www.trip.skyscanner.com/user/yelena-konetchy/passport/austin',
#  'https://www.trip.skyscanner.com/user/bailey-k_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/ramona-flume/passport/austin',
#  'https://www.trip.skyscanner.com/user/patty-drew/passport/austin',
#  'https://www.trip.skyscanner.com/user/nina-pena_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/tiffany-z/passport/austin',
#  'https://www.trip.skyscanner.com/user/meg-brooker/passport/austin',
#  'https://www.trip.skyscanner.com/user/brent-wistrom/passport/austin',
#  'https://www.trip.skyscanner.com/user/stephanie-asmus/passport/austin',
#  'https://www.trip.skyscanner.com/user/amit-anandwala/passport/austin',
#  'https://www.trip.skyscanner.com/user/mark-payne_3/passport/austin',
#  'https://www.trip.skyscanner.com/user/melody-lowe/passport/austin',
#  'https://www.trip.skyscanner.com/user/elisa-regulski/passport/austin',
#  'https://www.trip.skyscanner.com/user/ryan-onyxhotels/passport/austin',
#  'https://www.trip.skyscanner.com/user/stephen-andears/passport/austin',
#  'https://www.trip.skyscanner.com/user/alice-chase/passport/austin',
#  'https://www.trip.skyscanner.com/user/mary-beth-c_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/justine_14/passport/austin',
#  'https://www.trip.skyscanner.com/user/jen-knoedl/passport/austin',
#  'https://www.trip.skyscanner.com/user/travis-katz/passport/austin',
#  'https://www.trip.skyscanner.com/user/broke-girls-guide/passport/austin',
#  'https://www.trip.skyscanner.com/user/mary-lou-t_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/persis-ratouis/passport/austin',
#  'https://www.trip.skyscanner.com/user/laraye-rushing/passport/austin',
#  'https://www.trip.skyscanner.com/user/netta-drimer_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/paula_19/passport/austin',
#  'https://www.trip.skyscanner.com/user/diane-austin/passport/austin',
#  'https://www.trip.skyscanner.com/user/suzanne-wyble/passport/austin',
#  'https://www.trip.skyscanner.com/user/audrey-lo-travelingaudrey_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/libby_3/passport/austin',
#  'https://www.trip.skyscanner.com/user/connie-chang/passport/austin',
#  'https://www.trip.skyscanner.com/user/patrick-keltner/passport/austin',
#  'https://www.trip.skyscanner.com/user/van-le/passport/austin',
#  'https://www.trip.skyscanner.com/user/baxter-jackson/passport/austin',
#  'https://www.trip.skyscanner.com/user/steve-deangelo/passport/austin',
#  'https://www.trip.skyscanner.com/user/susan-l_19/passport/austin',
#  'https://www.trip.skyscanner.com/user/jessica-abramson/passport/austin',
#  'https://www.trip.skyscanner.com/user/alicia-moylan/passport/austin',
#  'https://www.trip.skyscanner.com/user/nina-h_3/passport/austin',
#  'https://www.trip.skyscanner.com/user/keane/passport/austin',
#  'https://www.trip.skyscanner.com/user/derrick-sison/passport/austin',
#  'https://www.trip.skyscanner.com/user/deborah-peacock_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/rebecca-goglia-beccabandit/passport/austin',
#  'https://www.trip.skyscanner.com/user/rie_4/passport/austin',
#  'https://www.trip.skyscanner.com/user/frances-nguyen-ha/passport/austin',
#  'https://www.trip.skyscanner.com/user/dale-c_3/passport/austin',
#  'https://www.trip.skyscanner.com/user/april-mccormick-miner/passport/austin',
#  'https://www.trip.skyscanner.com/user/katherine_9/passport/austin',
#  'https://www.trip.skyscanner.com/user/gmack/passport/austin',
#  'https://www.trip.skyscanner.com/user/sharon-d_7/passport/austin',
#  'https://www.trip.skyscanner.com/user/tyson-bramer/passport/austin',
#  'https://www.trip.skyscanner.com/user/john-ewalt/passport/austin',
#  'https://www.trip.skyscanner.com/user/kathleen-r_13/passport/austin',
#  'https://www.trip.skyscanner.com/user/randall-chase/passport/austin',
#  'https://www.trip.skyscanner.com/user/john-conrad/passport/austin',
#  'https://www.trip.skyscanner.com/user/tom-hale/passport/austin',
#  'https://www.trip.skyscanner.com/user/john-abdou/passport/austin',
#  'https://www.trip.skyscanner.com/user/nina-beall/passport/austin',
#  'https://www.trip.skyscanner.com/user/jean-l_7/passport/austin',
#  'https://www.trip.skyscanner.com/user/michael-s_50/passport/austin',
#  'https://www.trip.skyscanner.com/user/terry-e/passport/austin',
#  'https://www.trip.skyscanner.com/user/tracey-thad/passport/austin',
#  'https://www.trip.skyscanner.com/user/beatriz-martinez_7/passport/austin',
#  'https://www.trip.skyscanner.com/user/mimosa-chloe/passport/austin',
#  'https://www.trip.skyscanner.com/user/rachel_54/passport/austin',
#  'https://www.trip.skyscanner.com/user/kian-r/passport/austin',
#  'https://www.trip.skyscanner.com/user/wanderlustoneer/passport/austin',
#  'https://www.trip.skyscanner.com/user/travel-leisure/passport/austin',
#  'https://www.trip.skyscanner.com/user/chelsea-s_4/passport/austin',
#  'https://www.trip.skyscanner.com/user/laura-o_3/passport/austin',
#  'https://www.trip.skyscanner.com/user/jacqueline-g_3/passport/austin',
#  'https://www.trip.skyscanner.com/user/julie-k_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/katie-pierce/passport/austin',
#  'https://www.trip.skyscanner.com/user/azpaul/passport/austin',
#  'https://www.trip.skyscanner.com/user/morison-woo/passport/austin',
#  'https://www.trip.skyscanner.com/user/carlos-m_7/passport/austin',
#  'https://www.trip.skyscanner.com/user/katie-and-ben-e/passport/austin',
#  'https://www.trip.skyscanner.com/user/satish-talim/passport/austin',
#  'https://www.trip.skyscanner.com/user/chereen-f/passport/austin',
#  'https://www.trip.skyscanner.com/user/sally-s_4/passport/austin',
#  'https://www.trip.skyscanner.com/user/jenna-million/passport/austin',
#  'https://www.trip.skyscanner.com/user/cassandra_5/passport/austin',
#  'https://www.trip.skyscanner.com/user/jeremy-k_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/kevin-farrell/passport/austin',
#  'https://www.trip.skyscanner.com/user/derek-h_3/passport/austin',
#  'https://www.trip.skyscanner.com/user/dennis-janssen/passport/austin',
#  'https://www.trip.skyscanner.com/user/amy-simoes/passport/austin',
#  'https://www.trip.skyscanner.com/user/trinidad-m_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/vicki-t/passport/austin',
#  'https://www.trip.skyscanner.com/user/kayko/passport/austin',
#  'https://www.trip.skyscanner.com/user/jana-b/passport/austin',
#  'https://www.trip.skyscanner.com/user/shelby-s/passport/austin',
#  'https://www.trip.skyscanner.com/user/sobe-collins/passport/austin',
#  'https://www.trip.skyscanner.com/user/e-g_4/passport/austin',
#  'https://www.trip.skyscanner.com/user/avani-j/passport/austin',
#  'https://www.trip.skyscanner.com/user/ashley-d/passport/austin',
#  'https://www.trip.skyscanner.com/user/essjoy/passport/austin',
#  'https://www.trip.skyscanner.com/user/joel-rasmussen/passport/austin',
#  'https://www.trip.skyscanner.com/user/daniel-o/passport/austin',
#  'https://www.trip.skyscanner.com/user/joshua-stewart_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/karen-m_9/passport/austin',
#  'https://www.trip.skyscanner.com/user/danial-hanafian/passport/austin',
#  'https://www.trip.skyscanner.com/user/sharon-k-yapp/passport/austin',
#  'https://www.trip.skyscanner.com/user/leslie-w_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/david-valdez_3/passport/austin',
#  'https://www.trip.skyscanner.com/user/k-angel-horne/passport/austin',
#  'https://www.trip.skyscanner.com/user/raechel-hurd/passport/austin',
#  'https://www.trip.skyscanner.com/user/raman/passport/austin',
#  'https://www.trip.skyscanner.com/user/badrisk/passport/austin',
#  'https://www.trip.skyscanner.com/user/helena_4/passport/austin',
#  'https://www.trip.skyscanner.com/user/jonathan-s_16/passport/austin',
#  'https://www.trip.skyscanner.com/user/traci/passport/austin',
#  'https://www.trip.skyscanner.com/user/karrie-l/passport/austin',
#  'https://www.trip.skyscanner.com/user/jpkaulmann/passport/austin',
#  'https://www.trip.skyscanner.com/user/tasha-b/passport/austin',
#  'https://www.trip.skyscanner.com/user/pattys-places/passport/austin',
#  'https://www.trip.skyscanner.com/user/ashley-s_13/passport/austin',
#  'https://www.trip.skyscanner.com/user/alexandra-richmond/passport/austin',
#  'https://www.trip.skyscanner.com/user/mackenzie/passport/austin',
#  'https://www.trip.skyscanner.com/user/bob-and-pam/passport/austin',
#  'https://www.trip.skyscanner.com/user/nicolas-sauveur/passport/austin',
#  'https://www.trip.skyscanner.com/user/leigh-virkus/passport/austin',
#  'https://www.trip.skyscanner.com/user/sola-lodge/passport/austin',
#  'https://www.trip.skyscanner.com/user/ginger-s_3/passport/austin',
#  'https://www.trip.skyscanner.com/user/craig-weichmann/passport/austin',
#  'https://www.trip.skyscanner.com/user/robin-sanders/passport/austin',
#  'https://www.trip.skyscanner.com/user/michelle-k_10/passport/austin',
#  'https://www.trip.skyscanner.com/user/henry-nguyen_5/passport/austin',
#  'https://www.trip.skyscanner.com/user/colleen-sweazy/passport/austin',
#  'https://www.trip.skyscanner.com/user/molly-wardlaw/passport/austin',
#  'https://www.trip.skyscanner.com/user/malou-morato-dugtong/passport/austin',
#  'https://www.trip.skyscanner.com/user/angie-m_9/passport/austin',
#  'https://www.trip.skyscanner.com/user/tarina-peterson/passport/austin',
#  'https://www.trip.skyscanner.com/user/angela-liu_3/passport/austin',
#  'https://www.trip.skyscanner.com/user/clara-geffroy/passport/austin',
#  'https://www.trip.skyscanner.com/user/kelly-a_8/passport/austin',
#  'https://www.trip.skyscanner.com/user/julia-p/passport/austin',
#  'https://www.trip.skyscanner.com/user/lindsay-coston-fields/passport/austin',
#  'https://www.trip.skyscanner.com/user/scott-mcgaraghan/passport/austin',
#  'https://www.trip.skyscanner.com/user/richard-james/passport/austin',
#  'https://www.trip.skyscanner.com/user/melissa_51/passport/austin',
#  'https://www.trip.skyscanner.com/user/guy_10/passport/austin',
#  'https://www.trip.skyscanner.com/user/shonda/passport/austin',
#  'https://www.trip.skyscanner.com/user/doug-j_4/passport/austin',
#  'https://www.trip.skyscanner.com/user/alan-g_5/passport/austin',
#  'https://www.trip.skyscanner.com/user/kelly-k_9/passport/austin',
#  'https://www.trip.skyscanner.com/user/allan-z/passport/austin',
#  'https://www.trip.skyscanner.com/user/natalie-nokeo/passport/austin',
#  'https://www.trip.skyscanner.com/user/wendy-p_6/passport/austin',
#  'https://www.trip.skyscanner.com/user/mzmessynessy/passport/austin',
#  'https://www.trip.skyscanner.com/user/mela-mcgary/passport/austin',
#  'https://www.trip.skyscanner.com/user/andrew-w_3/passport/austin',
#  'https://www.trip.skyscanner.com/user/kristen-kachotravels/passport/austin',
#  'https://www.trip.skyscanner.com/user/bibi-javed/passport/austin',
#  'https://www.trip.skyscanner.com/user/sarah_80/passport/austin',
#  'https://www.trip.skyscanner.com/user/brenda-g_14/passport/austin',
#  'https://www.trip.skyscanner.com/user/lillie-s/passport/austin',
#  'https://www.trip.skyscanner.com/user/katharina-h_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/jayne-g_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/maria-coco-m/passport/austin',
#  'https://www.trip.skyscanner.com/user/melissa-s_16/passport/austin',
#  'https://www.trip.skyscanner.com/user/forrest-b/passport/austin',
#  'https://www.trip.skyscanner.com/user/steve-atwater/passport/austin',
#  'https://www.trip.skyscanner.com/user/holly-w_4/passport/austin',
#  'https://www.trip.skyscanner.com/user/christina-de-la-torre/passport/austin',
#  'https://www.trip.skyscanner.com/user/sean-r/passport/austin',
#  'https://www.trip.skyscanner.com/user/andi-w/passport/austin',
#  'https://www.trip.skyscanner.com/user/robin-j/passport/austin',
#  'https://www.trip.skyscanner.com/user/elle-hiltunen/passport/austin',
#  'https://www.trip.skyscanner.com/user/patrick-rech_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/eliot-e/passport/austin',
#  'https://www.trip.skyscanner.com/user/sondra-greig/passport/austin',
#  'https://www.trip.skyscanner.com/user/bradley-jackson/passport/austin',
#  'https://www.trip.skyscanner.com/user/lee-a_3/passport/austin',
#  'https://www.trip.skyscanner.com/user/eunice-cauich/passport/austin',
#  'https://www.trip.skyscanner.com/user/tory-k/passport/austin',
#  'https://www.trip.skyscanner.com/user/vivian-c/passport/austin',
#  'https://www.trip.skyscanner.com/user/glen-l/passport/austin',
#  'https://www.trip.skyscanner.com/user/scott-c_5/passport/austin',
#  'https://www.trip.skyscanner.com/user/h12-outdoor-cafe/passport/austin',
#  'https://www.trip.skyscanner.com/user/sharon-bubz-z/passport/austin',
#  'https://www.trip.skyscanner.com/user/carlie-yapp/passport/austin',
#  'https://www.trip.skyscanner.com/user/lorraine_7/passport/austin',
#  'https://www.trip.skyscanner.com/user/pam-k_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/florencia-pettigrew-prada/passport/austin',
#  'https://www.trip.skyscanner.com/user/robert-rodriguez_8/passport/austin',
#  'https://www.trip.skyscanner.com/user/hannah-shirley/passport/austin',
#  'https://www.trip.skyscanner.com/user/niranjana-ramkumar/passport/austin',
#  'https://www.trip.skyscanner.com/user/leslie-g_4/passport/austin',
#  'https://www.trip.skyscanner.com/user/cora-brown/passport/austin',
#  'https://www.trip.skyscanner.com/user/loren-r_3/passport/austin',
#  'https://www.trip.skyscanner.com/user/dominique-d/passport/austin',
#  'https://www.trip.skyscanner.com/user/minnie-pilli/passport/austin',
#  'https://www.trip.skyscanner.com/user/david-k_25/passport/austin',
#  'https://www.trip.skyscanner.com/user/julie-h_11/passport/austin',
#  'https://www.trip.skyscanner.com/user/dorothy-molencupp/passport/austin',
#  'https://www.trip.skyscanner.com/user/rosemary-tsai/passport/austin',
#  'https://www.trip.skyscanner.com/user/cindy-chow_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/teresa-d_4/passport/austin',
#  'https://www.trip.skyscanner.com/user/sam_38/passport/austin',
#  'https://www.trip.skyscanner.com/user/gabriel_8/passport/austin',
#  'https://www.trip.skyscanner.com/user/nikolina-keil/passport/austin',
#  'https://www.trip.skyscanner.com/user/rebecca-m_11/passport/austin',
#  'https://www.trip.skyscanner.com/user/jared-m/passport/austin',
#  'https://www.trip.skyscanner.com/user/maggie-g_4/passport/austin',
#  'https://www.trip.skyscanner.com/user/stephen-bugno/passport/austin',
#  'https://www.trip.skyscanner.com/user/john-w_28/passport/austin',
#  'https://www.trip.skyscanner.com/user/zachary-p/passport/austin',
#  'https://www.trip.skyscanner.com/user/riane-yates/passport/austin',
#  'https://www.trip.skyscanner.com/user/janet-george/passport/austin',
#  'https://www.trip.skyscanner.com/user/casa-de-olivia/passport/austin',
#  'https://www.trip.skyscanner.com/user/elizabeth-perez_8/passport/austin',
#  'https://www.trip.skyscanner.com/user/michael-b_106/passport/austin',
#  'https://www.trip.skyscanner.com/user/maggie-li_3/passport/austin',
#  'https://www.trip.skyscanner.com/user/richard-p_2/passport/austin',
#  'https://www.trip.skyscanner.com/user/lee-lytle/passport/austin',
#  'https://www.trip.skyscanner.com/user/marsha-h_5/passport/austin',
#  'https://www.trip.skyscanner.com/user/edward-melendez_3/passport/austin',
#  'https://www.trip.skyscanner.com/user/meghan-johnson_2/passport/austin']

# %% [markdown]
# # Define scraping function to loop through urls

# %%
def scrape_test(urls): # function to scrape through urls
    last_height = driver.execute_script("return document.body.scrollHeight") # Using selenium, when page is loaded, get the height of the bottom of the page
    while True: # while this is still the very bottom of the page

        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);") # Scroll down to bottom
        sleep(15)   # Wait to load page

        new_height = driver.execute_script("return document.body.scrollHeight") # Calculate new scroll height and compare with last scroll height
        if new_height == last_height:     # if the new height reaches the bottom then break

            break
        last_height = new_height          # if the new hight is not the very bottom then keep scrolling and repeating this process

    soup = BeautifulSoup(driver.page_source, 'lxml')                         # load page from beautiful soup and control selenium(driver)
    for review in soup.find_all('div', {'class': 'moment'}):
            #find all of the information needed and save to variables, if no information found save as no information
            try:
                place_name = review.find('a', {'class': 'place_name'}).text         
            except:
                place_name = 'no place'
            try:
                category = review.find('small', {'class': 'place_type'}).text
            except:
                category = 'no category'
            try:
                rating = review.find('div', {'aria-label': True}).attrs['aria-label']
            except:
                rating = 'no rating'
            try:
                review_text = review.find('div', {'class': 'row review'}).text
            except:
                review_text = "no text"         
            user_name = url.split('/')[4]
            df.loc[len(df)] = [place_name, category, rating, user_name, review_text]  # add all to the end of the dataframe

# %% [markdown]
# # Use scraper function to loop through urls

# %%
# scraper in process
df = pd.DataFrame(columns=['place_name', 'category', 'rating', 'user_name', 'review_text']) # create new dataframe with specific columns
driver = webdriver.Chrome(executable_path="./chromedriver/macos/chromedriver")              # Load Selenium driver
driver.get(url)   # sends browser to desired url
sleep(4)          # sleep is important, because website will not allow scraper to get information if the driver starts too quickly
cookies = driver.find_element_by_xpath('//*[@id="cookie-banner-root"]/section/div/div/div/button')    # use selenium to click on I accept cookies banner
cookies.click()
sleep(4)

for url in urls[150:200]:   # I scraped in 4 waves of 50 urls each
    sleep(2)
    driver.get(url)         # have selenium fetch information from the url
    scrape_test(url)        # carry url to the function to scrape the pages information
driver.quit                 # end the driver after using
# Out:
# <bound method WebDriver.quit of <selenium.webdriver.chrome.webdriver.WebDriver (session="7537059bdc238cdecc3cdd023465423e")>>

# %%
df.head() # view dataframe
# Out:
#                                             place_name         category  \
# 0                                               Austin             City
# 1                                Boggy Creek Greenbelt       Attraction
# 2                              Zilker Botanical Garden       Attraction
# 3                                              Walmart       Attraction
# 4                                      Star Seeds Cafe       Restaurant
# 5                                               Austin             City
# 6                                Blanton Museum of Art       Attraction
# 7                            Stevie Ray Vaughan Statue       Attraction
# 8                            Four Seasons Hotel Austin            Hotel
# 9                       Alamo Drafthouse - South Lamar       Attraction
# 10   The Driskill - in the Unbound Collection by Hyatt            Hotel
# 11                  Bullock Texas State History Museum       Attraction
# 12                                        Caffé Medici       Restaurant
# 13                                      Torchy's Tacos       Restaurant
# 14                            I Love You So Much Mural       Attraction
# 15                                              Austin             City
# 16                                       Threadgill's        Restaurant
# 17                                         Little Deli       Restaurant
# 18                                    Continental Club       Attraction
# 19                   Austin City Limits Music Festival       Attraction
# 20                                     Amy's Ice Cream       Restaurant
# 21                                                SXSW       Attraction
# 22                               South Congress Avenue       Attraction
# 23                            Zilker Metropolitan Park       Attraction
# 24                                 Barton Springs Pool       Attraction
# 25                         crestview minimax -- CLOSED       Attraction
# 26                       Ginnys Little Longhorn Saloon       Attraction
# 27                                          6th Street       Attraction
# 28                       University of Texas at Austin       Attraction
# 29   Walk To Train, Grocery, Restaurants, Pool & Pa...  Vacation Rental
# ..                                                 ...              ...
# 615                                         Taco Shack       Restaurant
# 616                     Tres Amigos Cantina Restaurant       Restaurant
# 617                                   Uncommon Objects       Attraction
# 618                                             Luby's       Restaurant
# 619                                             Austin             City
# 620                               Ruby's BBQ -- CLOSED       Restaurant
# 621                                      Threadgill's        Restaurant
# 622            The Green Mesquite Bbq & More -- CLOSED       Restaurant
# 623                       Mangia Chicago Stuffed Pizza       Restaurant
# 624                               Hyatt Regency Austin            Hotel
# 625                                             Austin             City
# 626                            The Carillon Restaurant       Restaurant
# 627                     Rudy's Country Store & Bar-B-Q       Restaurant
# 628                              South Congress Avenue       Attraction
# 629       Austin Bergstrom International Airport (AUS)       Attraction
# 630                          South Congress Bridge Bat       Attraction
# 631                     Bess Bistro on Pecan -- CLOSED       Restaurant
# 632                               Hyatt Regency Austin            Hotel
# 633                           Torchy's Tacos -- CLOSED       Restaurant
# 634                                            Chuy's        Restaurant
# 635                                             Austin             City
# 636                                     Torchy's Tacos       Restaurant
# 637                                      Torchy's Taco       Restaurant
# 638                                     Torchy's Tacos       Restaurant
# 639                                     Torchy's Tacos       Restaurant
# 640                                     Torchy's Tacos       Restaurant
# 641                                   Kerbey Lane Cafe       Restaurant
# 642                  Mayfield Park and Nature Preserve       Attraction
# 643                                         Mt Bonnell       Attraction
# 644                          McKinney Falls State Park       Attraction
#
#         rating          user_name  \
# 0      5 stars       mzmessynessy
# 1      5 stars       mzmessynessy
# 2      5 stars       mzmessynessy
# 3      5 stars       mzmessynessy
# 4      5 stars       mzmessynessy
# 5    no rating        mela-mcgary
# 6      5 stars        mela-mcgary
# 7      5 stars        mela-mcgary
# 8      5 stars        mela-mcgary
# 9      5 stars        mela-mcgary
# 10     5 stars        mela-mcgary
# 11     4 stars        mela-mcgary
# 12     3 stars        mela-mcgary
# 13     3 stars        mela-mcgary
# 14     3 stars        mela-mcgary
# 15   no rating         andrew-w_3
# 16     5 stars         andrew-w_3
# 17     5 stars         andrew-w_3
# 18     5 stars         andrew-w_3
# 19     5 stars         andrew-w_3
# 20     5 stars         andrew-w_3
# 21     5 stars         andrew-w_3
# 22     5 stars         andrew-w_3
# 23     5 stars         andrew-w_3
# 24     5 stars         andrew-w_3
# 25     4 stars         andrew-w_3
# 26     4 stars         andrew-w_3
# 27     3 stars         andrew-w_3
# 28     3 stars         andrew-w_3
# 29   no rating         andrew-w_3
# ..         ...                ...
# 615    5 stars  dorothy-molencupp
# 616    5 stars  dorothy-molencupp
# 617    4 stars  dorothy-molencupp
# 618    2 stars  dorothy-molencupp
# 619    4 stars      rosemary-tsai
# 620    4 stars      rosemary-tsai
# 621    2 stars      rosemary-tsai
# 622     1 star      rosemary-tsai
# 623     1 star      rosemary-tsai
# 624     1 star      rosemary-tsai
# 625  no rating       cindy-chow_2
# 626    5 stars       cindy-chow_2
# 627    4 stars       cindy-chow_2
# 628    4 stars       cindy-chow_2
# 629    4 stars       cindy-chow_2
# 630    4 stars       cindy-chow_2
# 631    3 stars       cindy-chow_2
# 632    3 stars       cindy-chow_2
# 633  no rating       cindy-chow_2
# 634  no rating       cindy-chow_2
# 635  no rating         teresa-d_4
# 636    5 stars         teresa-d_4
# 637    5 stars         teresa-d_4
# 638    5 stars         teresa-d_4
# 639    5 stars         teresa-d_4
# 640    5 stars         teresa-d_4
# 641    5 stars         teresa-d_4
# 642    5 stars         teresa-d_4
# 643    5 stars         teresa-d_4
# 644    5 stars         teresa-d_4
#
#                                            review_text
# 0    Just stepping fresh outta zilker botanical gar...
# 1    So this quaint little park offers a nice littl...
# 2    Oh be still my beating heart! Beautiful! Broke...
# 3    Ok so my shopping experience at this Austin lo...
# 4    First spot I stopped to just soak up the Austi...
# 5                                              no text
# 6    Had a really great time here. Enjoyed the gift...
# 7    Very cool to see an SRV statue. We went at nig...
# 8                                              no text
# 9                                              no text
# 10   Very beautiful hotel inside and out. I especia...
# 11   The special prohibition exhibit was the best h...
# 12   I get just regular coffee and add a touch of c...
# 13   Pretty good, worth a try. I prefer my taco tru...
# 14   Smaller than anticipated. We didn't try the co...
# 15                                             no text
# 16                               Awesome home cookin'!
# 17   Walk and get a pizza or a really good sandwich...
# 18   Best music club in town! Every night is a good...
# 19   2 weeks this year. Soak it all in at Zilker park.
# 20   One of these really close to the house plus Ph...
# 21                                      SXSW nuf said.
# 22   Eat at Guero's taco bar and go to the Continen...
# 23   ACL baby!!! This is where it happens the first...
# 24   Austin has 2 seasons, hot and not so hot. So e...
# 25   Great if you need an item or two for cooking d...
# 26   One of Becca and I's favorite places on earth ...
# 27   Best bring your drinking hat if you head to ol...
# 28   Great if you want to learn but also a good pla...
# 29                                             no text
# ..                                                 ...
# 615  Tuesday and Thursday are enchilada plate days....
# 616  This is the go to after work place for dinner ...
# 617  Great stuff and friendly staff. A great weeken...
# 618  The food here was cold and prices are high. Th...
# 619  To live there, nahhhh, CA is so much better. B...
# 620  This is a MUST STOP place for some REAL TEXAN ...
# 621  A good burger, but too over cooked. I think, i...
# 622  Yelp, NOT GOOD at all. I don't like it..... I ...
# 623  A good burger, but too over cooked. I think, i...
# 624  The only thing good about this hotel is their ...
# 625                                            no text
# 626  Delicious food and great service! I had a pork...
# 627  The barbecue is delicious, especially the bris...
# 628  A very cute neighborhood with lots of cute ind...
# 629  A very convenient airport. The walk from the r...
# 630  An amazing sight to see so many bats streaming...
# 631  This is Sandra Bullock's restaurant, and I was...
# 632  Good location, with rooms overlooking the rive...
# 633                                            no text
# 634                                            no text
# 635                                            no text
# 636  different, delicious twist on local tacos. sev...
# 637                                            no text
# 638                                            no text
# 639                                            no text
# 640  great local place for austin style tacos. nice...
# 641  great local place for tasty and natural breakf...
# 642  peacocks roam the park and trails. fantastic p...
# 643  fantastic views of lake austin. walk up quite ...
# 644  beautiful natural falls and hiking trails loca...
#
# [645 rows x 5 columns]

# %%
df['user_name'].value_counts() # make sure each usernames matches up with their review count, some users have deleted posts which may have the numbers slightly off
# Out:
# lee-a_3                      45
# maria-coco-m                 37
# robin-j                      34
# holly-w_4                    32
# forrest-b                    27
# melissa-s_16                 22
# lillie-s                     21
# andi-w                       20
# eliot-e                      20
# bibi-javed                   19
# jayne-g_2                    15
# andrew-w_3                   15
# sean-r                       15
# sarah_80                     14
# steve-atwater                11
# brenda-g_14                  11
# cindy-chow_2                 10
# tory-k                       10
# teresa-d_4                   10
# robert-rodriguez_8           10
# dominique-d                  10
# loren-r_3                    10
# vivian-c                     10
# david-k_25                   10
# pam-k_2                      10
# kristen-kachotravels         10
# scott-c_5                    10
# bradley-jackson              10
# leslie-g_4                   10
# hannah-shirley               10
# sharon-bubz-z                10
# lorraine_7                   10
# minnie-pilli                 10
# glen-l                       10
# mela-mcgary                  10
# patrick-rech_2                9
# sondra-greig                  9
# carlie-yapp                   9
# h12-outdoor-cafe              9
# elle-hiltunen                 8
# eunice-cauich                 7
# niranjana-ramkumar            7
# florencia-pettigrew-prada     7
# cora-brown                    7
# dorothy-molencupp             7
# rosemary-tsai                 6
# mzmessynessy                  5
# christina-de-la-torre         4
# katharina-h_2                 3
# Name: user_name, dtype: int64

# %% [markdown]
# # Save dataframe to csv

# %%
df.to_csv('./text_reviews_150-200.csv')
